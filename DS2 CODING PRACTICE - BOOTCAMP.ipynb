# %%
import pandas as pd

# %%
users = pd.read_csv('user.tbl', sep='|')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
type(users)
# Out:
# pandas.core.frame.DataFrame

# %%
users.head(15)
#print first 15 rows
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301

# %%
users.tail(10)
#prints last 10 rows
# Out:
#      user_id  age gender     occupation zip_code
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
users.index
#number of rows
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %%
users.columns
#number of columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
users.gender
#no brackets because this is an attribute of the data, not a function/method in python that you can call on. 
#could also do users['gender']
# Out:
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
#       ..
# 938    F
# 939    M
# 940    M
# 941    F
# 942    M
# Name: gender, Length: 943, dtype: object

# %%
users.dtypes
#important that zip code is an object so any values beginning with a '0' is not read incorrectly
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
users.shape
#used for validation for checking that data is all still there
# Out:
# (943, 5)

# %%
users.values
#returns values as an array
# Out:
# array([[1, 24, 'M', 'technician', '85711'],
#        [2, 53, 'F', 'other', '94043'],
#        [3, 23, 'M', 'writer', '32067'],
#        ...,
#        [941, 20, 'M', 'student', '97229'],
#        [942, 48, 'F', 'librarian', '78209'],
#        [943, 22, 'M', 'student', '77841']], dtype=object)

# %%
users['age'].shape
# Out:
# (943,)

# %%
users[['gender']]
#calling on a data frame
# Out:
#     gender
# 0        M
# 1        F
# 2        M
# 3        M
# 4        F
# ..     ...
# 938      F
# 939      M
# 940      M
# 941      F
# 942      M
#
# [943 rows x 1 columns]

# %%
users[['gender']].shape
# Out:
# (943, 1)

# %%
users.describe()
#numerical data only
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
include_object = users.describe(include=['object'])
include_object
#objects only
# Out:
#        gender occupation zip_code
# count     943        943      943
# unique      2         21      795
# top         M    student    55414
# freq      670        196        9

# %%
users.describe(include='all')
#numerical and objects
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
users['gender'].describe()
# Out:
# count     943
# unique      2
# top         M
# freq      670
# Name: gender, dtype: object

# %%
users.age.mean()
#calculate the mean of age - table.column.calculation()
# Out:
# 34.05196182396607

# %%
users.age.hist();
#add a ; for visualisations

# %%
users.age.plot(kind='bar', figsize=(12,12));

# %%
users.age.value_counts().plot(kind='bar', figsize=(12,12));
#counts of ages

# %%
users.age.value_counts().sort_index().plot(kind='bar', figsize=(12,12));
#order by index

# %%
users.age.value_counts().sort_index().plot(kind='bar', colormap= 'PiYG', figsize =(12,12));

# %%
import pandas as pd
drinks = pd.read_csv('drinks.csv')
#import new dataset

# %%
#print the first 5 rows of data
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#print last 5 rows
drinks.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
#examine the index, datatypes, shape
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.shape
# Out:
# (193, 6)

# %%
#print first 5 rows of beer_servings column

drinks.beer_servings.head()
# Out:
# 0      0
# 1     89
# 2     25
# 3    245
# 4    217
# Name: beer_servings, dtype: int64

# %%
drinks['beer_servings'].head()
# Out:
# 0      0
# 1     89
# 2     25
# 3    245
# 4    217
# Name: beer_servings, dtype: int64

# %%
#calculate mean of beer_servings
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
#count the number of occurences of each continent value
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %% [markdown]
# #Filtering and Sorting

# %%
#testing whether users are less than 20
users['age'] < 20
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# Name: age, Length: 943, dtype: bool

# %%
#make it a data frame
users[users['age'] <20].head()
# Out:
#     user_id  age gender occupation zip_code
# 29       30    7      M    student    55436
# 35       36   19      F    student    93117
# 51       52   18      F    student    55105
# 56       57   16      M       none    84010
# 66       67   17      M    student    60402

# %%
#assigning a variable as a way of cleaning data
mask = users.age < 20
users[mask]
# Out:
#      user_id  age gender occupation zip_code
# 29        30    7      M    student    55436
# 35        36   19      F    student    93117
# 51        52   18      F    student    55105
# 56        57   16      M       none    84010
# 66        67   17      M    student    60402
# ..       ...  ...    ...        ...      ...
# 871      872   19      F    student    74078
# 879      880   13      M    student    83702
# 886      887   14      F    student    27249
# 903      904   17      F    student    61073
# 924      925   18      F   salesman    49036
#
# [77 rows x 5 columns]

# %%
#select only students
mask2 = users.occupation=='student'
#make it a new variable in case you want to use it later
student_frame = users[mask2]
student_frame.head()
# Out:
#     user_id  age gender occupation zip_code
# 8         9   29      M    student    01002
# 29       30    7      M    student    55436
# 31       32   28      F    student    78741
# 32       33   23      M    student    27510
# 35       36   19      F    student    93117

# %%
#unique values
users.age.unique()
# Out:
# array([24, 53, 23, 33, 42, 57, 36, 29, 39, 28, 47, 45, 49, 21, 30, 35, 40,
#        26, 25, 32, 41,  7, 38, 20, 19, 27, 18, 22, 37, 16, 50, 31, 51, 17,
#        48, 34, 43, 60, 55, 15, 61, 44, 54, 59, 46, 13, 52, 56, 14, 66, 62,
#        11, 65, 68, 63, 64, 10, 73, 58, 69, 70], dtype=int64)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#return all beer servings less than 89 AND (&) from the EU
less_than_89 = (drinks.beer_servings < 89) & (drinks.continent =='EU')
drinks[less_than_89].head()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 7              Armenia             21              179             11
# 10          Azerbaijan             21               46              5
# 21  Bosnia-Herzegovina             76              173              8
# 64             Georgia             52              100            149
# 83               Italy             85               42            237
#
#     total_litres_of_pure_alcohol continent
# 7                            3.8        EU
# 10                           1.3        EU
# 21                           4.6        EU
# 64                           5.4        EU
# 83                           6.5        EU

# %%
# Use the pipe | as an OR operator
less_than_89 = (drinks.beer_servings < 89) | (drinks.continent =='EU')
drinks[less_than_89].head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 7      Armenia             21              179             11
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 7                           3.8        EU

# %%
less_than_89.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
# the OR operator takes priority over the &
less_than_100 = (drinks.beer_servings <=100) & (drinks.continent == 'AF') | (drinks.wine_servings > 200)
drinks[less_than_100].head()
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 2     Algeria             25                0             14
# 3     Andorra            245              138            312
# 6   Argentina            193               25            221
# 8   Australia            261               72            212
# 16    Belgium            295               84            212
#
#     total_litres_of_pure_alcohol continent
# 2                            0.7        AF
# 3                           12.4        EU
# 6                            8.3        SA
# 8                           10.4        OC
# 16                          10.5        EU

# %%
#the long way of selecting occupations
multiple_occupations = (users.occupation == 'student') | (users.occupation =='doctor') | (users.occupation =='lawyer')
users[multiple_occupations].head()
# Out:
#     user_id  age gender occupation zip_code
# 8         9   29      M    student    01002
# 9        10   53      M     lawyer    90703
# 29       30    7      M    student    55436
# 31       32   28      F    student    78741
# 32       33   23      M    student    27510

# %%
# the quick way of returning multiple conditions - isin
lawstudoc = users[users.occupation.isin(['student', 'doctor','lawyer'])]
lawstudoc.head()
# Out:
#     user_id  age gender occupation zip_code
# 8         9   29      M    student    01002
# 9        10   53      M     lawyer    90703
# 29       30    7      M    student    55436
# 31       32   28      F    student    78741
# 32       33   23      M    student    27510

# %%
#sort in desc order
users.sort_values('age', ascending=False).head()
# Out:
#      user_id  age gender     occupation zip_code
# 480      481   73      M        retired    37771
# 802      803   70      M  administrator    78212
# 766      767   70      M       engineer    00000
# 859      860   70      F        retired    48322
# 584      585   69      M      librarian    98501

# %%
#sort in asc order
users.sort_values('age', ascending=True).head()
# Out:
#      user_id  age gender occupation zip_code
# 29        30    7      M    student    55436
# 470      471   10      M    student    77459
# 288      289   11      M       none    94619
# 879      880   13      M    student    83702
# 608      609   13      F    student    55106

# %%
#sort by occupation
users.sort_values('occupation', ascending=True).head()
# Out:
#      user_id  age gender     occupation zip_code
# 71        72   48      F  administrator    73034
# 767      768   29      M  administrator    12866
# 325      326   41      M  administrator    15235
# 856      857   35      F  administrator    V1G4L
# 88        89   43      F  administrator    68106

# %%
#decide the order of multiple columns - occupation in ascending and age in descending
users.sort_values(['occupation','age'], ascending = [True, False]).head()
# Out:
#      user_id  age gender     occupation zip_code
# 802      803   70      M  administrator    78212
# 265      266   62      F  administrator    78756
# 130      131   59      F  administrator    15237
# 818      819   59      M  administrator    40205
# 6          7   57      M  administrator    91344

# %%
# inplace function changes analysis

# %%
#1) Filter the DataFrame to only include European countries

EU_only = (drinks.continent =='EU')
drinks[EU_only].head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 1      Albania             89              132             54
# 3      Andorra            245              138            312
# 7      Armenia             21              179             11
# 9      Austria            279               75            191
# 10  Azerbaijan             21               46              5
#
#     total_litres_of_pure_alcohol continent
# 1                            4.9        EU
# 3                           12.4        EU
# 7                            3.8        EU
# 9                            9.7        EU
# 10                           1.3        EU

# %%
#2) Filter the DataFrame to only include European countries with wine_servings > 300

EU_wine_over_300 = (drinks.continent =='EU') & (drinks.wine_servings >300)
drinks[EU_wine_over_300].head()
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 61     France            127              151            370
# 136  Portugal            194               67            339
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 61                           11.8        EU
# 136                          11.0        EU

# %%
#3) Calculate the average `beer_servings` for all of Europe

drinks.beer_servings[EU_only].mean()

#drinks[EU_only]['beer_servings'].mean() is the same
# Out:
# 193.77777777777777

# %%
#4) Determine which 10 countries have the highest `total_litres_of_pure_alcohol`.
drinks.sort_values(['total_litres_of_pure_alcohol'], ascending=False)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 15          Belarus            142              373             42
# 98        Lithuania            343              244             56
# 3           Andorra            245              138            312
# 68          Grenada            199              438             28
# 45   Czech Republic            361              170            134
# ..              ...            ...              ...            ...
# 79             Iran              0                0              0
# 90           Kuwait              0                0              0
# 128        Pakistan              0                0              0
# 97            Libya              0                0              0
# 0       Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 15                           14.4        EU
# 98                           12.9        EU
# ...

# %%
print(drinks.columns)
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %% [markdown]
# #RENAME COLUMNS

# %%
#inplace function = rewrites the data so you don't have to keep renaming
drinks.rename(columns={'beer_servings':'beer', 'wine_servings':'wine'}, inplace=True)
# Out:
#          country  beer  spirit_servings  wine  total_litres_of_pure_alcohol  \
# 0    Afghanistan     0                0     0                           0.0
# 1        Albania    89              132    54                           4.9
# 2        Algeria    25                0    14                           0.7
# 3        Andorra   245              138   312                          12.4
# 4         Angola   217               57    45                           5.9
# ..           ...   ...              ...   ...                           ...
# 188    Venezuela   333              100     3                           7.7
# 189      Vietnam   111                2     1                           2.0
# 190        Yemen     6                0     0                           0.1
# 191       Zambia    32               19     4                           2.5
# 192     Zimbabwe    64               18     4                           4.7
#
#     continent
# 0          AS
# 1          EU
# ...

# %%
#list of column names to reassign to already loaded data
drinks_cols = ['country','beer','spirit','wine','litres','continent']

#Before you load your data in, you can specifiy column names
#drinks = pd.read_csv('drinks.csv', header=0, names=drinks_cols)

# %%
#we have already loaded the data in so....
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
#reassign
drinks.columns = drinks_cols

# %%
drinks
# Out:
#          country  beer  spirit  wine  litres continent
# 0    Afghanistan     0       0     0     0.0        AS
# 1        Albania    89     132    54     4.9        EU
# 2        Algeria    25       0    14     0.7        AF
# 3        Andorra   245     138   312    12.4        EU
# 4         Angola   217      57    45     5.9        AF
# ..           ...   ...     ...   ...     ...       ...
# 188    Venezuela   333     100     3     7.7        SA
# 189      Vietnam   111       2     1     2.0        AS
# 190        Yemen     6       0     0     0.1        AS
# 191       Zambia    32      19     4     2.5        AF
# 192     Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %% [markdown]
# #CREATE COLUMNS

# %%
#generalising to a new value for the whole column. Otehrwise, you will have to write a list for each index to be replaced.

drinks['new_column'] = 'new_value'
drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent new_column
# 0  Afghanistan     0       0     0     0.0        AS  new_value
# 1      Albania    89     132    54     4.9        EU  new_value
# 2      Algeria    25       0    14     0.7        AF  new_value
# 3      Andorra   245     138   312    12.4        EU  new_value
# 4       Angola   217      57    45     5.9        AF  new_value

# %%
#new calculated column
drinks['total_servings'] = drinks.beer + drinks.wine + drinks.spirit
drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent new_column  \
# 0  Afghanistan     0       0     0     0.0        AS  new_value
# 1      Albania    89     132    54     4.9        EU  new_value
# 2      Algeria    25       0    14     0.7        AF  new_value
# 3      Andorra   245     138   312    12.4        EU  new_value
# 4       Angola   217      57    45     5.9        AF  new_value
#
#    total_servings
# 0               0
# 1             275
# 2              39
# 3             695
# 4             319

# %%
#convert litres to mls
drinks['mL'] = drinks.litres * 1000
drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent new_column  \
# 0  Afghanistan     0       0     0     0.0        AS  new_value
# 1      Albania    89     132    54     4.9        EU  new_value
# 2      Algeria    25       0    14     0.7        AF  new_value
# 3      Andorra   245     138   312    12.4        EU  new_value
# 4       Angola   217      57    45     5.9        AF  new_value
#
#    total_servings       mL
# 0               0      0.0
# 1             275   4900.0
# 2              39    700.0
# 3             695  12400.0
# 4             319   5900.0

# %%
#delete a column - have to spec that axis = 1 for it to be a column. Row is axis=0
drinks.drop(['new_column'], axis=1, inplace=True)

# %%
#drops row 69
drinks.drop(69)
# Out:
#          country  beer  spirit  wine  litres continent new_column  \
# 0    Afghanistan     0       0     0     0.0        AS  new_value
# 1        Albania    89     132    54     4.9        EU  new_value
# 2        Algeria    25       0    14     0.7        AF  new_value
# 3        Andorra   245     138   312    12.4        EU  new_value
# 4         Angola   217      57    45     5.9        AF  new_value
# ..           ...   ...     ...   ...     ...       ...        ...
# 188    Venezuela   333     100     3     7.7        SA  new_value
# 189      Vietnam   111       2     1     2.0        AS  new_value
# 190        Yemen     6       0     0     0.1        AS  new_value
# 191       Zambia    32      19     4     2.5        AF  new_value
# 192     Zimbabwe    64      18     4     4.7        AF  new_value
#
#      total_servings       mL
# 0                 0      0.0
# 1               275   4900.0
# 2                39    700.0
# 3               695  12400.0
# ...

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent  total_servings       mL
# 0  Afghanistan     0       0     0     0.0        AS               0      0.0
# 1      Albania    89     132    54     4.9        EU             275   4900.0
# 2      Algeria    25       0    14     0.7        AF              39    700.0
# 3      Andorra   245     138   312    12.4        EU             695  12400.0
# 4       Angola   217      57    45     5.9        AF             319   5900.0

# %% [markdown]
# #Day 2

# %%
import pandas as pd
drinks = pd.read_csv('drinks.csv')

# %%
#all info - identifying nulls
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 7.6+ KB

# %%
#methods of dealing with nulls - imputing, removing, ignore, filling it in
#VALUE_COUNTS FUNCTION DOESN'T TAKE INTO ACCOUNT NULLS
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
#count the total
drinks.continent.value_counts().sum()
# Out:
# 170

# %%
#Includes nulls as new value (NaN = not a number)
drinks.continent.value_counts(dropna=False)
# Out:
# AF     53
# EU     45
# AS     44
# NaN    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
#view nulls in a series - tests each row as a boolean
drinks.continent.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %%
#The opposite, tests if the value IS NOT null
drinks.continent.notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 188    True
# 189    True
# 190    True
# 191    True
# 192    True
# Name: continent, Length: 193, dtype: bool

# %%
#sum of null values - True is 1 and False is 0
drinks.continent.isnull().sum()
# Out:
# 23

# %%
drinks[drinks.continent.isnull()].head(10)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 5    Antigua & Barbuda            102              128             45
# 11             Bahamas            122              176             51
# 14            Barbados            143              173             36
# 17              Belize            263              114              8
# 32              Canada            240              122            100
# 41          Costa Rica            149               87             11
# 43                Cuba             93              137              5
# 50            Dominica             52              286             26
# 51  Dominican Republic            193              147              9
# 54         El Salvador             52               69              2
#
#     total_litres_of_pure_alcohol continent
# 5                            4.9       NaN
# 11                           6.3       NaN
# 14                           6.3       NaN
# ...

# %%
drinks[drinks.continent.notnull()].head(10)
# Out:
#         country  beer_servings  spirit_servings  wine_servings  \
# 0   Afghanistan              0                0              0
# 1       Albania             89              132             54
# 2       Algeria             25                0             14
# 3       Andorra            245              138            312
# 4        Angola            217               57             45
# 6     Argentina            193               25            221
# 7       Armenia             21              179             11
# 8     Australia            261               72            212
# 9       Austria            279               75            191
# 10   Azerbaijan             21               46              5
#
#     total_litres_of_pure_alcohol continent
# 0                            0.0        AS
# 1                            4.9        EU
# 2                            0.7        AF
# 3                           12.4        EU
# 4                            5.9        AF
# ...

# %%
drinks.isnull().sum()
drinks.isnull().sum().plot(kind= 'bar', figsize(5,5));
# Out:
#   File "<ipython-input-21-9d705edd91bd>", line 2
#     drinks.isnull().sum().plot(kind= 'bar', figsize(5,5));
#                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
#drop the null values - rows with 1+ nulls are removed. 
drop = drinks.dropna()

# %%
#only drop a row if ALL values are null
drinks.dropna(how='all')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
#filling in nulls e.g. north america / NA
drinks.continent.fillna(value='NA' , inplace=True)

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
#turn off null filter before loading data in
drinks = pd.read_csv('drinks.csv', header = 0, na_filter=False)

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
#shows default arguments
drinks.info?

# %%
import pandas as pd
info = pd.read_csv('ufo.csv')

# %%
info
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 80538                Neligh             NaN         CIRCLE    NE
# 80539          Uhrichsville             NaN          LIGHT    OH
# 80540                Tucson        RED BLUE            NaN    AZ
# 80541           Orland park             RED          LIGHT    IL
# 80542              Loughman             NaN          LIGHT    FL
#
#                   Time
# 0       6/1/1930 22:00
# 1      6/30/1930 20:00
# 2      2/15/1931 14:00
# 3       6/1/1931 13:00
# 4      4/18/1933 19:00
# ...                ...
# ...

# %%
#rename column headers through a list
new_names = ['city', 'colours', 'shape', 'state', 'time']

# %%
#reassign names of coloumns as a variable
info.columns = new_names

# %%
#check they have changed
info
# Out:
#                        city   colours     shape state             time
# 0                    Ithaca       NaN  TRIANGLE    NY   6/1/1930 22:00
# 1               Willingboro       NaN     OTHER    NJ  6/30/1930 20:00
# 2                   Holyoke       NaN      OVAL    CO  2/15/1931 14:00
# 3                   Abilene       NaN      DISK    KS   6/1/1931 13:00
# 4      New York Worlds Fair       NaN     LIGHT    NY  4/18/1933 19:00
# ...                     ...       ...       ...   ...              ...
# 80538                Neligh       NaN    CIRCLE    NE   9/4/2014 23:20
# 80539          Uhrichsville       NaN     LIGHT    OH    9/5/2014 1:14
# 80540                Tucson  RED BLUE       NaN    AZ    9/5/2014 2:40
# 80541           Orland park       RED     LIGHT    IL    9/5/2014 3:43
# 80542              Loughman       NaN     LIGHT    FL    9/5/2014 5:30
#
# [80543 rows x 5 columns]

# %%
#find colour counts
info.colours.value_counts()
# Out:
# ORANGE                          5216
# RED                             4809
# GREEN                           1897
# BLUE                            1855
# YELLOW                           842
# RED ORANGE                       486
# RED GREEN                        469
# RED BLUE                         445
# RED GREEN BLUE                   166
# GREEN BLUE                       147
# RED YELLOW                       146
# ORANGE YELLOW                    137
# ORANGE GREEN                      66
# ORANGE BLUE                       58
# YELLOW GREEN                      53
# RED YELLOW BLUE                   36
# RED YELLOW GREEN                  35
# RED ORANGE YELLOW                 32
# YELLOW BLUE                       27
# RED YELLOW GREEN BLUE             26
# RED ORANGE BLUE                   21
# ORANGE GREEN BLUE                 13
# YELLOW GREEN BLUE                 13
# RED ORANGE GREEN                  12
# RED ORANGE GREEN BLUE              8
# ...

# %%
Virginia = 'VA'

# %%
info.isnull().sum()
# Out:
# city          47
# colours    63509
# shape       8402
# state          0
# time           0
# dtype: int64

# %%
info.dropna()
# Out:
#                  city colours      shape state             time
# 12             Belton     RED     SPHERE    SC  6/30/1939 20:00
# 19         Bering Sea     RED      OTHER    AK  4/30/1943 23:00
# 36         Portsmouth     RED  FORMATION    VA   7/10/1945 1:30
# 44          Blairsden   GREEN     SPHERE    CA  6/30/1946 19:00
# 82           San Jose    BLUE    CHEVRON    CA  7/15/1947 21:00
# ...               ...     ...        ...   ...              ...
# 80524         Olympia     RED      LIGHT    WA   9/4/2014 21:10
# 80525       Iowa City    BLUE      LIGHT    IA   9/4/2014 21:11
# 80528  North Royalton     RED   TRIANGLE    OH   9/4/2014 21:30
# 80536         Wyoming     RED       DISK    PA   9/4/2014 23:00
# 80541     Orland park     RED      LIGHT    IL    9/5/2014 3:43
#
# [15510 rows x 5 columns]

# %%
info.shape
# Out:
# (80543, 5)

# %%
#what is the most common city for people in VA?

Virginia = info.state == 'VA'
info[Virginia].city.value_counts().head(1)
# Out:
# Virginia Beach    110
# Name: city, dtype: int64

# %%
#print a dataframe showing only records from VA, arlington

VA_ARL = (info.state == 'VA') & (info.city == 'Arlington')

# %%
info[VA_ARL].head()
# Out:
#             city colours    shape state              time
# 202    Arlington   GREEN     OVAL    VA   7/13/1952 21:00
# 6300   Arlington     NaN  CHEVRON    VA    5/5/1990 21:40
# 10278  Arlington     NaN     DISK    VA   5/27/1997 15:30
# 14527  Arlington     NaN    OTHER    VA   9/10/1999 21:41
# 17984  Arlington     RED     DISK    VA  11/19/2000 22:00

# %%
#count missing values in each column
info.isnull().sum()
# Out:
# city          47
# colours    63509
# shape       8402
# state          0
# time           0
# dtype: int64

# %%
#how many rows remain if we drop all rows with any missing values?
drop_nulls = info.dropna()
drop_nulls.shape
# Out:
# (15510, 5)

# %%
# permanently drop any rows with nulls
info.dropna(how='any', inplace=True)
info
# Out:
#                  city colours      shape state             time
# 12             Belton     RED     SPHERE    SC  6/30/1939 20:00
# 19         Bering Sea     RED      OTHER    AK  4/30/1943 23:00
# 36         Portsmouth     RED  FORMATION    VA   7/10/1945 1:30
# 44          Blairsden   GREEN     SPHERE    CA  6/30/1946 19:00
# 82           San Jose    BLUE    CHEVRON    CA  7/15/1947 21:00
# ...               ...     ...        ...   ...              ...
# 80524         Olympia     RED      LIGHT    WA   9/4/2014 21:10
# 80525       Iowa City    BLUE      LIGHT    IA   9/4/2014 21:11
# 80528  North Royalton     RED   TRIANGLE    OH   9/4/2014 21:30
# 80536         Wyoming     RED       DISK    PA   9/4/2014 23:00
# 80541     Orland park     RED      LIGHT    IL    9/5/2014 3:43
#
# [15510 rows x 5 columns]

# %% [markdown]
# #split apply combine

# %%
# split a dataset by grouping, apply a calculation, then combine to aggregate into an insight
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.rename({'beer_servings':'beer', 'spirit_servings': 'spirit', 'wine_servings':'wine', 'total_litres_of_pure_alcohol': 'litres'}, axis=1, inplace=True)

# %%
drinks
# Out:
#          country  beer  spirit  wine  litres continent
# 0    Afghanistan     0       0     0     0.0        AS
# 1        Albania    89     132    54     4.9        EU
# 2        Algeria    25       0    14     0.7        AF
# 3        Andorra   245     138   312    12.4        EU
# 4         Angola   217      57    45     5.9        AF
# ..           ...   ...     ...   ...     ...       ...
# 188    Venezuela   333     100     3     7.7        SA
# 189      Vietnam   111       2     1     2.0        AS
# 190        Yemen     6       0     0     0.1        AS
# 191       Zambia    32      19     4     2.5        AF
# 192     Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %%
#calculate mean of beer servings by continent
drinks.groupby('continent').beer.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# NA    145.434783
# OC     89.687500
# SA    175.083333
# Name: beer, dtype: float64

# %%
#calculate mean of each column by continent
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine    litres
# continent
# AF          61.471698   16.339623   16.264151  3.007547
# AS          37.045455   60.840909    9.068182  2.170455
# EU         193.777778  132.555556  142.222222  8.617778
# NA         145.434783  165.739130   24.521739  5.995652
# OC          89.687500   58.437500   35.625000  3.381250
# SA         175.083333  114.750000   62.416667  6.308333

# %%
#other aggregates but for wine 
drinks.groupby('continent').wine.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# NA          23.0   24.521739  28.266378  1.0   5.0   11.0   34.00  100.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
#select specific aggregates
drinks.groupby('continent').wine.agg(['count', 'mean'])
# Out:
#            count        mean
# continent
# AF            53   16.264151
# AS            44    9.068182
# EU            45  142.222222
# NA            23   24.521739
# OC            16   35.625000
# SA            12   62.416667

# %%
#sort by aggregate
drinks.groupby('continent').wine.agg(['count', 'mean']).sort_values('count')
# Out:
#            count        mean
# continent
# SA            12   62.416667
# OC            16   35.625000
# NA            23   24.521739
# AS            44    9.068182
# EU            45  142.222222
# AF            53   16.264151
